# %% [markdown]
# <a href="https://colab.research.google.com/github/Amazinghulk/Tech1200/blob/main/wek5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_grade(score, extra_credit=0):
    final_score = score + extra_credit
    if score >= 85:
        grade = "HD"
    elif score >= 70:
        grade = "D"
    elif score >= 50:
        grade = "C"
    elif score >= 35:
        grade = "P"
    else:
        grade = "F"
    return grade
print(calculate_grade(85, 5))
# Out:
# HD

# %%
def assign_grade(score, extra_credit=0):
    final_score = score + extra_credit
    if final_score >= 85:
        grade = "HD"
    elif final_score >= 70:
        grade = "D"
    elif final_score >= 50:
        grade = "C"
    elif final_score >= 35:
        grade = "p"
    else:
        grade = "f"
    return grade
print(assign_grade(70, 5))
# Out:
# D

# %%
def display_grading_system():
    print("HD: 85 - 100")
    print("D: 70 - 84")
    print("C: 50 - 69")
    print("P: 35 - 49")
    print("F: Below 35")


def assign_grade(score):
  if score >= 85:
    grade = 'HD'
  elif score >= 70:
    grade = 'D'
  elif score >= 50:
    grade = 'C'

  elif score >= 35:
    grade = 'P'
  else:
    grade = 'F'
  return grade

display_grading_system()
print(f"The grade for a score of 75 is: {assign_grade(75)}")
# Out:
# HD: 85 - 100
# D: 70 - 84
# C: 50 - 69
# P: 35 - 49
# F: Below 35
# The grade for a score of 75 is: D

# %%
def print_hello(name, surname):
 print('Welcome ' + name + ' ' + surname + ' to print_hello function')

print_hello('Mark', 'Smith')
# Out:
# Welcome Mark Smith to print_hello function

# %%
def display_grading_system():
    print("HD: 85 - 100")
    print("D: 70 - 84")
    print("C: 50 - 69")
    print("P: 35 - 49")
    print("F: Below 35")

display_grading_system()
# Out:
# HD: 85 - 100
# D: 70 - 84
# C: 50 - 69
# P: 35 - 49
# F: Below 35

# %%
def print_hello():
  print('#1 Welcome to print_hello function')
  print('#2 This code is outside of the print_hello function '
'and will be always printed regardless whether '
'print_hello function is called or not')
